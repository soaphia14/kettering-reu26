# %% [markdown]
# ### Setup
# Autoreload and imports

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Imports
import sys, os
from pathlib import Path
from art.attacks.evasion import FastGradientMethod, ProjectedGradientDescent, SaliencyMapMethod, CarliniL2Method
from art.defences.trainer import AdversarialTrainer, AdversarialTrainerTRADESPyTorch
import art.attacks.evasion.projected_gradient_descent.projected_gradient_descent_pytorch as _pgd_pt
_pgd_pt.compute_success = lambda *a, **kw: 0.0

sys.path.append(str(Path.cwd().parents[2]))

from utils.functions import get_windowed_data
from utils.notebook import get_model_classifier, clean_data_test, adv_test, FilenameLoader, get_filename_from_path, freeze_attack_cols

# %% [markdown]
# ### Define Inputs and Load Data

# %%
## Load checkpoint and data file paths
checkpoint_name, data_name, _ = FilenameLoader.rand_pos()

checkpoint_file= f"../../../saved_models/{checkpoint_name}"
data_file = f"../../../data/{data_name}"

# %%
## Load data
(x_train, y_train), (x_test, y_test), fed_dataset, scaler = get_windowed_data(data_file, 
                                                                      normalize=True, 
                                                                      train_perc=80)

# %% [markdown]
# ### Adversarial training

# %%
## Simple training - pgd at 0.05
from art.defences.trainer import AdversarialTrainer
import torch 

# Training vars
adv_train_eps = 0.01
adv_train_epochs = 5
adv_train_ratio = 0.5 

x_train_np = x_train.numpy()
y_train_np = y_train.numpy()

# Init vars
name = get_filename_from_path(checkpoint_file)
model, classifier = get_model_classifier(checkpoint_file)

print(f"=== Adversarial training: {name} | eps:  {adv_train_eps} ===")

adv_save_dir = f"../../fed/data-test/randpos_pgd-{adv_train_eps}_epochs-{adv_train_epochs}_clean"
os.makedirs(adv_save_dir, exist_ok=True)

# Get clean baseline 
print("> Before Clean Test")
before_clean_out = clean_data_test(
    model, classifier, x_test, y_test, 
    checkpoint_file=checkpoint_file, data_file=data_file,
    save_path=adv_save_dir,
    filename=f"before_clean_advtrained_{name}.json",
    save_results=True
)

# Check condition 1
print ("> Before Adv Test")
before_adv_out = adv_test(
    classifier, x_test, y_test, 
    checkpoint_file=checkpoint_file, data_file=data_file,
    end_index=len(y_test.numpy()),
    path=adv_save_dir,
    filename=f"before_adv_eps_{adv_train_eps}_advtrained_{name}.json",
    Attack=ProjectedGradientDescent,
    eps=adv_train_eps,
    max_iter = 5
)

# Run adv training
# freeze_attack_cols keeps rcvTime (col 0) untouched, same threat model as
# adv_test's freeze_cols default - a real attacker can't manipulate the
# receive timestamp, so FGSM shouldn't be allowed to "cheat" through it
# during training either.
print("> Running Adv Training")
attack = freeze_attack_cols(ProjectedGradientDescent(classifier, eps=adv_train_eps, max_iter=5), freeze_cols=(0,))
trainer = AdversarialTrainer(classifier, attacks=attack, ratio=adv_train_ratio)
trainer.fit(x_train_np, y_train_np, nb_epochs=adv_train_epochs)

# Re-evaluate after adversarial training
print("> After Clean Test")
after_clean_out = clean_data_test(
    model, classifier, x_test, y_test, 
    checkpoint_file=checkpoint_file, data_file=data_file,
    save_path=adv_save_dir,
    filename=f"after_clean_advtrained_{name}.json",
    save_results=True
)

print("> After Adv Test")
after_adv_f1 = []
for i in range(1, 31):
    eps = float(i/100)
    after_adv_out = adv_test(
        classifier, x_test, y_test, 
        checkpoint_file=checkpoint_file, data_file=data_file,
        end_index=len(y_test.numpy()),
        path=adv_save_dir,
        filename=f"after_adv_eps_{eps}_advtrained_{name}.json",
        Attack=FastGradientMethod,
        eps=eps,
    )
    after_adv_f1.append(after_adv_out["metrics"]["f1"])


# Save the adversarially-trained weights (loadable via utils.functions.load_model_checkpoint)
ckpt_out = f"{adv_save_dir}/advtrained_{name}.ckpt"
torch.save(model.learner.state_dict(), ckpt_out)
print(f"Saved adversarially-trained checkpoint to {ckpt_out}")

# Save config for reproducibility
import json
config = {
    "eps": adv_train_eps,
    "adv_train_epochs": adv_train_epochs,
    "adv_train_ratio": adv_train_ratio,
    "checkpoint_file": checkpoint_file,
    "attack": "ProjectedGradientDescent",
    "name": name,
}

with open(f"{adv_save_dir}/config.json", "w") as f:
    json.dump(config, f, indent=4)
    print("saved:", f"{adv_save_dir}/config.json")
# Out:
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# Checkpoint path exists!
# === Adversarial training: RandomPos-final | eps:  0.99 ===
# > Before Clean Test
# torch.Size([124774, 10, 2])
# 0.9991784882489942
# 0.9547720528729431
# Model got 1230683/1247740 right.
# Accuracy: 0.9863296840687964, Precision: 0.9991784882489942, Recall: 0.9547720528729431, F1 Score: 0.976470669379591
# 877040, 70.29028483498165% Zeroes, 370700 Non Zero entries.
# Saved to ../fed/data-test/randpos_pgd-0.00_epochs-5/before_clean_advtrained_RandomPos-final.json
# > Before Adv Test
# === Attack: ProjectedGradientDescent, kwargs: {'eps': 0.99, 'max_iter': 5} ===
# Accuracy:           0.0681
# Precision:          0.0874
# Recall:             0.2262
# F1:                 0.1260
# ASR (FNR):          0.7738
# False Positive Rate:0.9987
# TP=83838, TN=1118, FP=875922, FN=286862
# Time elapsed:       70.92s
# Saved metrics to ../fed/data-test/randpos_pgd-0.00_epochs-5/before_adv_eps_0.99_advtrained_RandomPos-final.json
# > Running Adv Training
# Precompute adv samples: 100%|██████████| 1/1 [00:00<00:00, 16644.06it/s]
# Adversarial training epochs: 100%|██████████| 5/5 [43:47<00:00, 525.59s/it]
# > After Clean Test
# torch.Size([124774, 10, 2])
# 0.9997665908086795
# 0.970593471810089
# Model got 1236755/1247740 right.
# Accuracy: 0.991196082517191, Precision: 0.9997665908086795, Recall: 0.970593471810089, F1 Score: 0.9849640629469889
# 877040, 70.29028483498165% Zeroes, 370700 Non Zero entries.
# Saved to ../fed/data-test/randpos_pgd-0.00_epochs-5/after_clean_advtrained_RandomPos-final.json
# > After Adv Test
# === Attack: FastGradientMethod, kwargs: {'eps': 0.01} ===
# Accuracy:           0.9502
# Precision:          0.9980
# Recall:             0.8340
# F1:                 0.9087
# ASR (FNR):          0.1660
# False Positive Rate:0.0007
# TP=309180, TN=876428, FP=612, FN=61520
# Time elapsed:       14.46s
# Saved metrics to ../fed/data-test/randpos_pgd-0.00_epochs-5/after_adv_eps_0.01_advtrained_RandomPos-final.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.02} ===
# Accuracy:           0.8207
# Precision:          0.9724
# Recall:             0.4079
# F1:                 0.5747
# ASR (FNR):          0.5921
# False Positive Rate:0.0049
# TP=151207, TN=872751, FP=4289, FN=219493
# Time elapsed:       15.13s
# Saved metrics to ../fed/data-test/randpos_pgd-0.00_epochs-5/after_adv_eps_0.02_advtrained_RandomPos-final.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.03} ===
# Accuracy:           0.7335
# Precision:          0.6748
# Recall:             0.1989
# F1:                 0.3072
# ASR (FNR):          0.8011
# False Positive Rate:0.0405
# TP=73733, TN=841500, FP=35540, FN=296967
# Time elapsed:       15.85s
# Saved metrics to ../fed/data-test/randpos_pgd-0.00_epochs-5/after_adv_eps_0.03_advtrained_RandomPos-final.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.04} ===
# Accuracy:           0.6744
# Precision:          0.3548
# Recall:             0.1171
# F1:                 0.1761
# ASR (FNR):          0.8829
# False Positive Rate:0.0900
# TP=43409, TN=798095, FP=78945, FN=327291
# Time elapsed:       16.83s
# Saved metrics to ../fed/data-test/randpos_pgd-0.00_epochs-5/after_adv_eps_0.04_advtrained_RandomPos-final.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.05} ===
# Accuracy:           0.6608
# Precision:          0.2620
# Recall:             0.0780
# F1:                 0.1203
# ASR (FNR):          0.9220
# False Positive Rate:0.0929
# TP=28933, TN=795539, FP=81501, FN=341767
# Time elapsed:       15.90s
# Saved metrics to ../fed/data-test/randpos_pgd-0.00_epochs-5/after_adv_eps_0.05_advtrained_RandomPos-final.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.06} ===
# Accuracy:           0.6574
# Precision:          0.2162
# Recall:             0.0584
# F1:                 0.0919
# ASR (FNR):          0.9416
# False Positive Rate:0.0895
# TP=21637, TN=798578, FP=78462, FN=349063
# Time elapsed:       14.84s
# Saved metrics to ../fed/data-test/randpos_pgd-0.00_epochs-5/after_adv_eps_0.06_advtrained_RandomPos-final.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.07} ===
# Accuracy:           0.6521
# Precision:          0.1746
# Recall:             0.0459
# F1:                 0.0727
# ASR (FNR):          0.9541
# False Positive Rate:0.0917
# TP=17010, TN=796615, FP=80425, FN=353690
# Time elapsed:       14.85s
# Saved metrics to ../fed/data-test/randpos_pgd-0.00_epochs-5/after_adv_eps_0.07_advtrained_RandomPos-final.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.08} ===
# Accuracy:           0.6480
# Precision:          0.1445
# Recall:             0.0375
# F1:                 0.0596
# ASR (FNR):          0.9625
# False Positive Rate:0.0940
# TP=13917, TN=794625, FP=82415, FN=356783
# Time elapsed:       14.60s
# Saved metrics to ../fed/data-test/randpos_pgd-0.00_epochs-5/after_adv_eps_0.08_advtrained_RandomPos-final.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.09} ===
# Accuracy:           0.6462
# Precision:          0.1246
# Recall:             0.0317
# F1:                 0.0505
# ASR (FNR):          0.9683
# False Positive Rate:0.0940
# TP=11743, TN=794572, FP=82468, FN=358957
# Time elapsed:       15.39s
# Saved metrics to ../fed/data-test/randpos_pgd-0.00_epochs-5/after_adv_eps_0.09_advtrained_RandomPos-final.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.1} ===
# Accuracy:           0.6451
# Precision:          0.1074
# Recall:             0.0266
# F1:                 0.0426
# ASR (FNR):          0.9734
# False Positive Rate:0.0934
# TP=9854, TN=795116, FP=81924, FN=360846
# Time elapsed:       15.29s
# Saved metrics to ../fed/data-test/randpos_pgd-0.00_epochs-5/after_adv_eps_0.1_advtrained_RandomPos-final.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.11} ===
# Accuracy:           0.6445
# Precision:          0.0935
# Recall:             0.0226
# F1:                 0.0364
# ASR (FNR):          0.9774
# False Positive Rate:0.0926
# TP=8383, TN=795786, FP=81254, FN=362317
# Time elapsed:       14.56s
# Saved metrics to ../fed/data-test/randpos_pgd-0.00_epochs-5/after_adv_eps_0.11_advtrained_RandomPos-final.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.12} ===
# Accuracy:           0.6441
# Precision:          0.0825
# Recall:             0.0196
# F1:                 0.0316
# ASR (FNR):          0.9804
# False Positive Rate:0.0920
# TP=7256, TN=796357, FP=80683, FN=363444
# Time elapsed:       16.42s
# Saved metrics to ../fed/data-test/randpos_pgd-0.00_epochs-5/after_adv_eps_0.12_advtrained_RandomPos-final.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.13} ===
# Accuracy:           0.6437
# Precision:          0.0734
# Recall:             0.0171
# F1:                 0.0278
# ASR (FNR):          0.9829
# False Positive Rate:0.0914
# TP=6356, TN=796842, FP=80198, FN=364344
# Time elapsed:       16.66s
# Saved metrics to ../fed/data-test/randpos_pgd-0.00_epochs-5/after_adv_eps_0.13_advtrained_RandomPos-final.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.14} ===
# Accuracy:           0.6435
# Precision:          0.0660
# Recall:             0.0152
# F1:                 0.0247
# ASR (FNR):          0.9848
# False Positive Rate:0.0909
# TP=5632, TN=797304, FP=79736, FN=365068
# Time elapsed:       15.11s
# Saved metrics to ../fed/data-test/randpos_pgd-0.00_epochs-5/after_adv_eps_0.14_advtrained_RandomPos-final.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.15} ===
# Accuracy:           0.6433
# Precision:          0.0600
# Recall:             0.0137
# F1:                 0.0223
# ASR (FNR):          0.9863
# False Positive Rate:0.0905
# TP=5070, TN=797659, FP=79381, FN=365630
# Time elapsed:       15.91s
# Saved metrics to ../fed/data-test/randpos_pgd-0.00_epochs-5/after_adv_eps_0.15_advtrained_RandomPos-final.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.16} ===
# Accuracy:           0.6433
# Precision:          0.0562
# Recall:             0.0127
# F1:                 0.0207
# ASR (FNR):          0.9873
# False Positive Rate:0.0901
# TP=4706, TN=798027, FP=79013, FN=365994
# Time elapsed:       14.94s
# Saved metrics to ../fed/data-test/randpos_pgd-0.00_epochs-5/after_adv_eps_0.16_advtrained_RandomPos-final.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.17} ===
# Accuracy:           0.6434
# Precision:          0.0529
# Recall:             0.0119
# F1:                 0.0194
# ASR (FNR):          0.9881
# False Positive Rate:0.0897
# TP=4395, TN=798392, FP=78648, FN=366305
# Time elapsed:       17.22s
# Saved metrics to ../fed/data-test/randpos_pgd-0.00_epochs-5/after_adv_eps_0.17_advtrained_RandomPos-final.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.18} ===
# Accuracy:           0.6435
# Precision:          0.0511
# Recall:             0.0114
# F1:                 0.0186
# ASR (FNR):          0.9886
# False Positive Rate:0.0893
# TP=4214, TN=798756, FP=78284, FN=366486
# Time elapsed:       17.43s
# Saved metrics to ../fed/data-test/randpos_pgd-0.00_epochs-5/after_adv_eps_0.18_advtrained_RandomPos-final.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.19} ===
# Accuracy:           0.6439
# Precision:          0.0499
# Recall:             0.0110
# F1:                 0.0180
# ASR (FNR):          0.9890
# False Positive Rate:0.0886
# TP=4079, TN=799311, FP=77729, FN=366621
# Time elapsed:       17.14s
# Saved metrics to ../fed/data-test/randpos_pgd-0.00_epochs-5/after_adv_eps_0.19_advtrained_RandomPos-final.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.2} ===
# Accuracy:           0.6445
# Precision:          0.0495
# Recall:             0.0108
# F1:                 0.0177
# ASR (FNR):          0.9892
# False Positive Rate:0.0877
# TP=4007, TN=800134, FP=76906, FN=366693
# Time elapsed:       16.39s
# Saved metrics to ../fed/data-test/randpos_pgd-0.00_epochs-5/after_adv_eps_0.2_advtrained_RandomPos-final.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.21} ===
# Accuracy:           0.6456
# Precision:          0.0500
# Recall:             0.0107
# F1:                 0.0176
# ASR (FNR):          0.9893
# False Positive Rate:0.0860
# TP=3967, TN=801595, FP=75445, FN=366733
# Time elapsed:       16.83s
# Saved metrics to ../fed/data-test/randpos_pgd-0.00_epochs-5/after_adv_eps_0.21_advtrained_RandomPos-final.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.22} ===
# Accuracy:           0.6478
# Precision:          0.0513
# Recall:             0.0106
# F1:                 0.0176
# ASR (FNR):          0.9894
# False Positive Rate:0.0829
# TP=3931, TN=804331, FP=72709, FN=366769
# Time elapsed:       15.06s
# Saved metrics to ../fed/data-test/randpos_pgd-0.00_epochs-5/after_adv_eps_0.22_advtrained_RandomPos-final.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.23} ===
# Accuracy:           0.6501
# Precision:          0.0532
# Recall:             0.0106
# F1:                 0.0176
# ASR (FNR):          0.9894
# False Positive Rate:0.0796
# TP=3922, TN=807239, FP=69801, FN=366778
# Time elapsed:       14.51s
# Saved metrics to ../fed/data-test/randpos_pgd-0.00_epochs-5/after_adv_eps_0.23_advtrained_RandomPos-final.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.24} ===
# Accuracy:           0.6525
# Precision:          0.0554
# Recall:             0.0106
# F1:                 0.0177
# ASR (FNR):          0.9894
# False Positive Rate:0.0761
# TP=3912, TN=810291, FP=66749, FN=366788
# Time elapsed:       14.81s
# Saved metrics to ../fed/data-test/randpos_pgd-0.00_epochs-5/after_adv_eps_0.24_advtrained_RandomPos-final.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.25} ===
# Accuracy:           0.6556
# Precision:          0.0584
# Recall:             0.0105
# F1:                 0.0179
# ASR (FNR):          0.9895
# False Positive Rate:0.0717
# TP=3905, TN=814125, FP=62915, FN=366795
# Time elapsed:       14.63s
# Saved metrics to ../fed/data-test/randpos_pgd-0.00_epochs-5/after_adv_eps_0.25_advtrained_RandomPos-final.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.26} ===
# Accuracy:           0.6584
# Precision:          0.0615
# Recall:             0.0105
# F1:                 0.0179
# ASR (FNR):          0.9895
# False Positive Rate:0.0678
# TP=3895, TN=817576, FP=59464, FN=366805
# Time elapsed:       14.54s
# Saved metrics to ../fed/data-test/randpos_pgd-0.00_epochs-5/after_adv_eps_0.26_advtrained_RandomPos-final.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.27} ===
# Accuracy:           0.6602
# Precision:          0.0638
# Recall:             0.0105
# F1:                 0.0180
# ASR (FNR):          0.9895
# False Positive Rate:0.0651
# TP=3891, TN=819926, FP=57114, FN=366809
# Time elapsed:       14.64s
# Saved metrics to ../fed/data-test/randpos_pgd-0.00_epochs-5/after_adv_eps_0.27_advtrained_RandomPos-final.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.28} ===
# Accuracy:           0.6617
# Precision:          0.0657
# Recall:             0.0105
# F1:                 0.0181
# ASR (FNR):          0.9895
# False Positive Rate:0.0630
# TP=3886, TN=821745, FP=55295, FN=366814
# Time elapsed:       15.25s
# Saved metrics to ../fed/data-test/randpos_pgd-0.00_epochs-5/after_adv_eps_0.28_advtrained_RandomPos-final.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.29} ===
# Accuracy:           0.6620
# Precision:          0.0659
# Recall:             0.0105
# F1:                 0.0180
# ASR (FNR):          0.9895
# False Positive Rate:0.0626
# TP=3876, TN=822116, FP=54924, FN=366824
# Time elapsed:       14.66s
# Saved metrics to ../fed/data-test/randpos_pgd-0.00_epochs-5/after_adv_eps_0.29_advtrained_RandomPos-final.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.3} ===
# Accuracy:           0.6622
# Precision:          0.0661
# Recall:             0.0104
# F1:                 0.0180
# ASR (FNR):          0.9896
# False Positive Rate:0.0623
# TP=3863, TN=822430, FP=54610, FN=366837
# Time elapsed:       14.46s
# Saved metrics to ../fed/data-test/randpos_pgd-0.00_epochs-5/after_adv_eps_0.3_advtrained_RandomPos-final.json
# Saved adversarially-trained checkpoint to ../fed/data-test/randpos_pgd-0.00_epochs-5/advtrained_RandomPos-final.ckpt

# %%
import json
config = {
    "eps": adv_train_eps,
    "adv_train_epochs": adv_train_epochs,
    "adv_train_ratio": adv_train_ratio,
    "checkpoint_file": checkpoint_file,
    "attack": "ProjectedGradientDescent",
    "name": name,
}

with open(f"{adv_save_dir}/config.json", "w") as f:
    json.dump(config, f, indent=4)
    print("saved:", f"{adv_save_dir}/config.json")
# Out:
# saved: ../fed/data-test/randpos-pgd-0.05/config.json

# %%
## Find lowerbound threshold - lowest eps that still
lo_eps = 0.07 # fgsm, from the previously done eps sweep, f1 = 0.7079755805153897 < 0.77

# %%
## Find upperbound threshold - highest eps that starts making benign wrong

import json, time, torch
# When f1 is at least 20 pts down from og (so 0.77)

# ratio = 0.5, epochs = 5, eps = 0.2 -> ran until eps = 0.99, ratio to low? (high-eps-iterative)
# ratio = 1.0, epochs = 5, eps = 0.1 -> clean f1 score dec immediately, ratio to high? (high-eps-iterative-ratio-1.0)
# ratio = 0.7, epochs = 5, eps = 0.1 -> running current (high-eps-iterative-ratio-0.7)

# Defined
clean_f1 = 0.976470669379591
threshold_diff = 0.2
working_eps = 0.9

# Training Hyperparams
adv_train_epochs = 5
adv_train_ratio = 0.7

# Var definitions
x_train_np = x_train.numpy()
y_train_np = y_train.numpy()
name = get_filename_from_path(checkpoint_file)
index = 1

# run once

while index < 2:
    start = time.time()
    print(f"\n\n>>> New eps: {working_eps}")
    # Reload classifier
    index = index + 1
    model, classifier = get_model_classifier(checkpoint_file)
    adv_save_dir = f"../fed/data-test/freeze-col-test/iter-{index}"
    os.makedirs(adv_save_dir, exist_ok=True)
    print(f"Saving to: {adv_save_dir}")

    ## Adv train model
    print("> Running Adv Training")
    attack = freeze_attack_cols(FastGradientMethod(classifier, eps=working_eps), freeze_cols=(0,))
    trainer = AdversarialTrainer(classifier, attack, ratio=adv_train_ratio)
    trainer.fit(x_train_np, y_train_np, nb_epochs=adv_train_epochs, batch_size=64)

    # Save model
    ckpt_out = f"{adv_save_dir}/advtrained_{name}.ckpt"
    torch.save(model.learner.state_dict(), ckpt_out)
    print(f"Saved adversarially-trained checkpoint to {ckpt_out}")

    ## Test model
    after_clean_out = clean_data_test(
        model, classifier, x_test, y_test, 
        checkpoint_file=checkpoint_file, data_file=data_file,
        save_path=adv_save_dir,
        filename=f"after_clean_advtrained_{name}.json",
        save_results=True
    )

    # Save config
    

    # Check if f1 is below
    adv_f1 = after_clean_out["wrapper"]["f1"]
    if (adv_f1 < clean_f1 - threshold_diff): 
        print(f"BREAKING WITH EPS {working_eps}")
        break
    else:
        print(f"f1 = {adv_f1} >  {clean_f1 - threshold_diff}")
        working_eps = round(working_eps + 0.01, 2)
        print(f"Increasing eps to {working_eps}")

print("goodbye world")


    
    

"""
- Start at ~ 0.2 eps
- Adv train model on the # of eps (save the model)
- Run clean test (and SAVE it)
- Check if it's below the threshold

* Can try just doing 10 points.. later (or just see from data)
"""
# Out:
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# >>> New eps: 0.9
# Checkpoint path exists!
# Saving to: ../fed/data-test/freeze-col-test/iter-2
# > Running Adv Training
# Precompute adv samples: 100%|██████████| 1/1 [00:00<00:00, 58254.22it/s]
# Adversarial training epochs: 100%|██████████| 5/5 [07:05<00:00, 85.16s/it]
# Saved adversarially-trained checkpoint to ../fed/data-test/freeze-col-test/iter-2/advtrained_RandomPos-final.ckpt
# Saved to ../fed/data-test/freeze-col-test/iter-2/after_clean_advtrained_RandomPos-final.json
# f1 = 0.9955288715845922 >  0.7764706693795911
# Increasing eps to 0.91
# goodbye world
# "\n- Start at ~ 0.2 eps\n- Adv train model on the # of eps (save the model)\n- Run clean test (and SAVE it)\n- Check if it's below the threshold\n\n* Can try just doing 10 points.. later (or just see from data)\n"

# %%
# y_train_np.sum(axis=1)[102]
# Out:
# np.int64(0)

# %%
## Find upperbound threshold - highest eps that starts making benign wrong

import json, time, torch
import numpy as np
# When f1 is at least 20 pts down from og (so 0.77)

# ratio = 0.5, epochs = 5, eps = 0.2 -> ran until eps = 0.99, ratio to low? (high-eps-iterative)
# ratio = 1.0, epochs = 5, eps = 0.1 -> clean f1 score dec immediately, ratio to high? (high-eps-iterative-ratio-1.0)
# ratio = 0.7, epochs = 5, eps = 0.1 -> running current (high-eps-iterative-ratio-0.7)

# Defined
clean_f1 = 0.976470669379591
threshold_diff = 0.2
working_eps = 0.1

# Training Hyperparams
adv_train_epochs = 5

# Var definitions
x_train_np = x_train.numpy()
y_train_np = (y_train.numpy() == 1).all(axis=1).astype(np.int64)
name = get_filename_from_path(checkpoint_file)
index = 2

# run once

while index < 3:
    start = time.time()
    print(f"\n\n>>> New eps: {working_eps}")
    # Reload classifier
    index = index + 1
    model, classifier = get_model_classifier(checkpoint_file, collapsed=True)
    classifier._reduce_labels = True
    adv_save_dir = f"../fed/data-test/trades-test/iter-{index}"
    os.makedirs(adv_save_dir, exist_ok=True)
    print(f"Saving to: {adv_save_dir}")

    ## Adv train model
    print("> Running Adv Training")
    attack = FastGradientMethod(classifier, eps=working_eps)
    trainer = AdversarialTrainerTRADESPyTorch(classifier, attack=attack, beta=0.6)
    trainer.fit(x_train_np, y_train_np, nb_epochs=adv_train_epochs, batch_size=64)

    # Save model
    ckpt_out = f"{adv_save_dir}/advtrained_{name}.ckpt"
    torch.save(model.learner.state_dict(), ckpt_out)
    print(f"Saved adversarially-trained checkpoint to {ckpt_out}")

    ## Test model
    after_clean_out = clean_data_test(
        model, classifier, x_test, y_test, 
        checkpoint_file=checkpoint_file, data_file=data_file,
        save_path=adv_save_dir,
        filename=f"after_clean_advtrained_{name}.json",
        save_results=True,
        collapsed=True
    )

    # Save config
    config = {
        "eps": working_eps,
        "adv_train_epochs": adv_train_epochs,
        "beta": 0.6,
        "clean_f1_baseline": clean_f1,
        "threshold_diff": threshold_diff,
        "index": index,
        "checkpoint_file": checkpoint_file,
        "name": name,
        "timeElapsedSec": (time.time() - start)
    }

    with open(f"{adv_save_dir}/config.json", "w") as f:
        json.dump(config, f, indent=4)

    # Check if f1 is below
    adv_f1 = after_clean_out["wrapper"]["f1"]
    if (adv_f1 < clean_f1 - threshold_diff): 
        print(f"BREAKING WITH EPS {working_eps}")
        break
    else:
        print(f"f1 = {adv_f1} >  {clean_f1 - threshold_diff}")
        working_eps = round(working_eps + 0.01, 2)
        print(f"Increasing eps to {working_eps}")

print("goodbye world")


    
    

"""
- Start at ~ 0.2 eps
- Adv train model on the # of eps (save the model)
- Run clean test (and SAVE it)
- Check if it's below the threshold

* Can try just doing 10 points.. later (or just see from data)
"""
# Out:
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# >>> New eps: 0.1
# Checkpoint path exists!
# Saving to: ../fed/data-test/trades-test/iter-3
# > Running Adv Training
# Adversarial Training TRADES - Epochs: 100%|██████████| 5/5 [12:13<00:00, 146.73s/it]
# Saved adversarially-trained checkpoint to ../fed/data-test/trades-test/iter-3/advtrained_RandomPos-final.ckpt
# Saved to ../fed/data-test/trades-test/iter-3/after_clean_advtrained_RandomPos-final.json
# f1 = 0.9970922762743267 >  0.7764706693795911
# Increasing eps to 0.11
# goodbye world
# "\n- Start at ~ 0.2 eps\n- Adv train model on the # of eps (save the model)\n- Run clean test (and SAVE it)\n- Check if it's below the threshold\n\n* Can try just doing 10 points.. later (or just see from data)\n"

# %%
min(3, 1)
# Out:
# 1
