# %% [markdown]
# ### Setup
# Autoreload and imports

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Imports
import sys, os
from pathlib import Path
from art.attacks.evasion import FastGradientMethod, ProjectedGradientDescent, SaliencyMapMethod, CarliniL2Method
from art.defences.trainer import AdversarialTrainer, AdversarialTrainerTRADESPyTorch
import art.attacks.evasion.projected_gradient_descent.projected_gradient_descent_pytorch as _pgd_pt
_pgd_pt.compute_success = lambda *a, **kw: 0.0

sys.path.append(str(Path.cwd().parents[1]))

from utils.functions import get_windowed_data
from utils.notebook import get_model_classifier, clean_data_test, adv_test, FilenameLoader, get_filename_from_path, freeze_attack_cols, freeze_benign_and_cols

# %% [markdown]
# ### Define Inputs and Load Data

# %%
class TestLoader:
    def __init__ (self, checkpoint_file, data_file, name):
        self.checkpoint_file = checkpoint_file
        self.data_file = data_file
        self.name = name
        print("Initialized")
    
    def load_data(self):
        (self.x_train, self.y_train), (self.x_test, self.y_test), fed_dataset, self.scaler = get_windowed_data(data_file, 
                                                                      normalize=True, 
                                                                      train_perc=80)
        self.x_train_np = self.x_train.numpy()
        self.y_train_np = self.y_train.numpy()
        print("Loaded Data")

    def load_model(self):
        self.model, self.classifier = get_model_classifier(self.checkpoint_file)

    def clean_test(self, save_dir : str, save_results : bool = True):
        clean_data_test(
            self.model, self.classifier, self.x_test, self.y_test, 
            checkpoint_file=self.checkpoint_file, data_file=self.data_file,
            save_path=save_dir,
            filename=f"before_clean_advtrained_{self.name}.json",
            save_results=save_results
        )

# %%
## Load checkpoint and data file paths
_, data_name, _ = FilenameLoader.rand_pos()

checkpoint_file= f"../../saved_models/adv_trained/RandPos-PGD-Evasion-30-30-200.ckpt"
data_file = f"../../data/{data_name}"

# %%
(x_train, y_train), (x_test, y_test), fed_dataset, scaler = get_windowed_data(data_file, 
                                                                      normalize=True, 
                                                                      train_perc=80)

# %% [markdown]
# ### Adversarial training

# %% [markdown]
# #### Clean Testing

# %%
print("> Before Adv Test")

model, classifier = get_model_classifier(checkpoint_file)
adv_save_dir = f"../fed/data-test/randpos-evasion_trained-30-30-200_no-retraining"
os.makedirs(adv_save_dir, exist_ok=True)
name = get_filename_from_path(checkpoint_file)

after_adv_f1 = []
for i in range(1, 31):
    eps = float(i/100)
    after_adv_out = adv_test(
        classifier, x_test, y_test, 
        checkpoint_file=checkpoint_file, data_file=data_file,
        end_index=len(y_test.numpy()),
        path=adv_save_dir+"/fgsm",
        filename=f"after_adv_eps_{eps}_advtrained_{name}.json",
        Attack=FastGradientMethod,
        eps=eps,
    )
    after_adv_f1.append(after_adv_out["metrics"]["f1"])
# Out:
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# /opt/anaconda3/envs/reu/lib/python3.11/site-packages/pytorch_lightning/trainer/setup.py:175: GPU available but not used. You can set it by doing `Trainer(accelerator='gpu')`.
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# > Before Adv Test
# Checkpoint path exists!
# === Attack: FastGradientMethod, kwargs: {'eps': 0.01} ===
# Accuracy:           0.9849
# Precision:          0.9965
# Recall:             0.9526
# F1:                 0.9741
# ASR (FNR):          0.0474
# False Positive Rate:0.0014
# TP=353129, TN=875800, FP=1240, FN=17571
# Time elapsed:       15.77s
# Saved metrics to ../fed/data-test/randpos-evasion_trained-30-30-200_no-retraining/fgsm/after_adv_eps_0.01_advtrained_RandPos-PGD-Evasion-30-30-200.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.02} ===
# Accuracy:           0.9823
# Precision:          0.9948
# Recall:             0.9453
# F1:                 0.9694
# ASR (FNR):          0.0547
# False Positive Rate:0.0021
# TP=350417, TN=875217, FP=1823, FN=20283
# Time elapsed:       14.69s
# Saved metrics to ../fed/data-test/randpos-evasion_trained-30-30-200_no-retraining/fgsm/after_adv_eps_0.02_advtrained_RandPos-PGD-Evasion-30-30-200.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.03} ===
# Accuracy:           0.9791
# Precision:          0.9924
# Recall:             0.9367
# F1:                 0.9638
# ASR (FNR):          0.0633
# False Positive Rate:0.0030
# TP=347239, TN=874383, FP=2657, FN=23461
# Time elapsed:       14.47s
# Saved metrics to ../fed/data-test/randpos-evasion_trained-30-30-200_no-retraining/fgsm/after_adv_eps_0.03_advtrained_RandPos-PGD-Evasion-30-30-200.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.04} ===
# Accuracy:           0.9734
# Precision:          0.9828
# Recall:             0.9268
# F1:                 0.9540
# ASR (FNR):          0.0732
# False Positive Rate:0.0068
# TP=343554, TN=871042, FP=5998, FN=27146
# Time elapsed:       14.19s
# Saved metrics to ../fed/data-test/randpos-evasion_trained-30-30-200_no-retraining/fgsm/after_adv_eps_0.04_advtrained_RandPos-PGD-Evasion-30-30-200.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.05} ===
# Accuracy:           0.9599
# Precision:          0.9465
# Recall:             0.9168
# F1:                 0.9314
# ASR (FNR):          0.0832
# False Positive Rate:0.0219
# TP=339858, TN=857831, FP=19209, FN=30842
# Time elapsed:       14.29s
# Saved metrics to ../fed/data-test/randpos-evasion_trained-30-30-200_no-retraining/fgsm/after_adv_eps_0.05_advtrained_RandPos-PGD-Evasion-30-30-200.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.06} ===
# Accuracy:           0.9227
# Precision:          0.8456
# Recall:             0.9050
# F1:                 0.8743
# ASR (FNR):          0.0950
# False Positive Rate:0.0698
# TP=335493, TN=815786, FP=61254, FN=35207
# Time elapsed:       14.55s
# Saved metrics to ../fed/data-test/randpos-evasion_trained-30-30-200_no-retraining/fgsm/after_adv_eps_0.06_advtrained_RandPos-PGD-Evasion-30-30-200.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.07} ===
# Accuracy:           0.8584
# Precision:          0.7076
# Recall:             0.8921
# F1:                 0.7892
# ASR (FNR):          0.1079
# False Positive Rate:0.1558
# TP=330718, TN=740388, FP=136652, FN=39982
# Time elapsed:       18.56s
# Saved metrics to ../fed/data-test/randpos-evasion_trained-30-30-200_no-retraining/fgsm/after_adv_eps_0.07_advtrained_RandPos-PGD-Evasion-30-30-200.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.08} ===
# Accuracy:           0.7770
# Precision:          0.5827
# Recall:             0.8783
# F1:                 0.7006
# ASR (FNR):          0.1217
# False Positive Rate:0.2658
# TP=325578, TN=643884, FP=233156, FN=45122
# Time elapsed:       14.82s
# Saved metrics to ../fed/data-test/randpos-evasion_trained-30-30-200_no-retraining/fgsm/after_adv_eps_0.08_advtrained_RandPos-PGD-Evasion-30-30-200.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.09} ===
# Accuracy:           0.6519
# Precision:          0.4548
# Recall:             0.8633
# F1:                 0.5957
# ASR (FNR):          0.1367
# False Positive Rate:0.4375
# TP=320030, TN=493364, FP=383676, FN=50670
# Time elapsed:       15.13s
# Saved metrics to ../fed/data-test/randpos-evasion_trained-30-30-200_no-retraining/fgsm/after_adv_eps_0.09_advtrained_RandPos-PGD-Evasion-30-30-200.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.1} ===
# Accuracy:           0.4944
# Precision:          0.3537
# Recall:             0.8485
# F1:                 0.4993
# ASR (FNR):          0.1515
# False Positive Rate:0.6553
# TP=314525, TN=302321, FP=574719, FN=56175
# Time elapsed:       16.08s
# Saved metrics to ../fed/data-test/randpos-evasion_trained-30-30-200_no-retraining/fgsm/after_adv_eps_0.1_advtrained_RandPos-PGD-Evasion-30-30-200.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.11} ===
# Accuracy:           0.3481
# Precision:          0.2912
# Recall:             0.8326
# F1:                 0.4315
# ASR (FNR):          0.1674
# False Positive Rate:0.8567
# TP=308661, TN=125681, FP=751359, FN=62039
# Time elapsed:       15.26s
# Saved metrics to ../fed/data-test/randpos-evasion_trained-30-30-200_no-retraining/fgsm/after_adv_eps_0.11_advtrained_RandPos-PGD-Evasion-30-30-200.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.12} ===
# Accuracy:           0.2812
# Precision:          0.2675
# Recall:             0.8168
# F1:                 0.4031
# ASR (FNR):          0.1832
# False Positive Rate:0.9452
# TP=302794, TN=48071, FP=828969, FN=67906
# Time elapsed:       15.07s
# Saved metrics to ../fed/data-test/randpos-evasion_trained-30-30-200_no-retraining/fgsm/after_adv_eps_0.12_advtrained_RandPos-PGD-Evasion-30-30-200.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.13} ===
# Accuracy:           0.2608
# Precision:          0.2591
# Recall:             0.8003
# F1:                 0.3915
# ASR (FNR):          0.1997
# False Positive Rate:0.9672
# TP=296687, TN=28740, FP=848300, FN=74013
# Time elapsed:       15.19s
# Saved metrics to ../fed/data-test/randpos-evasion_trained-30-30-200_no-retraining/fgsm/after_adv_eps_0.13_advtrained_RandPos-PGD-Evasion-30-30-200.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.14} ===
# Accuracy:           0.2508
# Precision:          0.2537
# Recall:             0.7836
# F1:                 0.3833
# ASR (FNR):          0.2164
# False Positive Rate:0.9744
# TP=290487, TN=22496, FP=854544, FN=80213
# Time elapsed:       14.62s
# Saved metrics to ../fed/data-test/randpos-evasion_trained-30-30-200_no-retraining/fgsm/after_adv_eps_0.14_advtrained_RandPos-PGD-Evasion-30-30-200.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.15} ===
# Accuracy:           0.2433
# Precision:          0.2488
# Recall:             0.7660
# F1:                 0.3756
# ASR (FNR):          0.2340
# False Positive Rate:0.9776
# TP=283953, TN=19613, FP=857427, FN=86747
# Time elapsed:       14.75s
# Saved metrics to ../fed/data-test/randpos-evasion_trained-30-30-200_no-retraining/fgsm/after_adv_eps_0.15_advtrained_RandPos-PGD-Evasion-30-30-200.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.16} ===
# Accuracy:           0.2365
# Precision:          0.2440
# Recall:             0.7479
# F1:                 0.3679
# ASR (FNR):          0.2521
# False Positive Rate:0.9796
# TP=277250, TN=17891, FP=859149, FN=93450
# Time elapsed:       15.40s
# Saved metrics to ../fed/data-test/randpos-evasion_trained-30-30-200_no-retraining/fgsm/after_adv_eps_0.16_advtrained_RandPos-PGD-Evasion-30-30-200.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.17} ===
# Accuracy:           0.2302
# Precision:          0.2391
# Recall:             0.7292
# F1:                 0.3602
# ASR (FNR):          0.2708
# False Positive Rate:0.9807
# TP=270326, TN=16890, FP=860150, FN=100374
# Time elapsed:       14.78s
# Saved metrics to ../fed/data-test/randpos-evasion_trained-30-30-200_no-retraining/fgsm/after_adv_eps_0.17_advtrained_RandPos-PGD-Evasion-30-30-200.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.18} ===
# Accuracy:           0.2241
# Precision:          0.2343
# Recall:             0.7105
# F1:                 0.3524
# ASR (FNR):          0.2895
# False Positive Rate:0.9815
# TP=263396, TN=16239, FP=860801, FN=107304
# Time elapsed:       16.07s
# Saved metrics to ../fed/data-test/randpos-evasion_trained-30-30-200_no-retraining/fgsm/after_adv_eps_0.18_advtrained_RandPos-PGD-Evasion-30-30-200.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.19} ===
# Accuracy:           0.2183
# Precision:          0.2295
# Recall:             0.6922
# F1:                 0.3448
# ASR (FNR):          0.3078
# False Positive Rate:0.9820
# TP=256595, TN=15805, FP=861235, FN=114105
# Time elapsed:       16.49s
# Saved metrics to ../fed/data-test/randpos-evasion_trained-30-30-200_no-retraining/fgsm/after_adv_eps_0.19_advtrained_RandPos-PGD-Evasion-30-30-200.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.2} ===
# Accuracy:           0.2126
# Precision:          0.2248
# Recall:             0.6738
# F1:                 0.3371
# ASR (FNR):          0.3262
# False Positive Rate:0.9824
# TP=249787, TN=15436, FP=861604, FN=120913
# Time elapsed:       15.44s
# Saved metrics to ../fed/data-test/randpos-evasion_trained-30-30-200_no-retraining/fgsm/after_adv_eps_0.2_advtrained_RandPos-PGD-Evasion-30-30-200.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.21} ===
# Accuracy:           0.2070
# Precision:          0.2200
# Recall:             0.6559
# F1:                 0.3295
# ASR (FNR):          0.3441
# False Positive Rate:0.9828
# TP=243155, TN=15096, FP=861944, FN=127545
# Time elapsed:       18.71s
# Saved metrics to ../fed/data-test/randpos-evasion_trained-30-30-200_no-retraining/fgsm/after_adv_eps_0.21_advtrained_RandPos-PGD-Evasion-30-30-200.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.22} ===
# Accuracy:           0.2013
# Precision:          0.2153
# Recall:             0.6381
# F1:                 0.3219
# ASR (FNR):          0.3619
# False Positive Rate:0.9833
# TP=236558, TN=14660, FP=862380, FN=134142
# Time elapsed:       17.08s
# Saved metrics to ../fed/data-test/randpos-evasion_trained-30-30-200_no-retraining/fgsm/after_adv_eps_0.22_advtrained_RandPos-PGD-Evasion-30-30-200.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.23} ===
# Accuracy:           0.1956
# Precision:          0.2104
# Recall:             0.6203
# F1:                 0.3142
# ASR (FNR):          0.3797
# False Positive Rate:0.9839
# TP=229942, TN=14164, FP=862876, FN=140758
# Time elapsed:       14.41s
# Saved metrics to ../fed/data-test/randpos-evasion_trained-30-30-200_no-retraining/fgsm/after_adv_eps_0.23_advtrained_RandPos-PGD-Evasion-30-30-200.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.24} ===
# Accuracy:           0.1901
# Precision:          0.2055
# Recall:             0.6023
# F1:                 0.3064
# ASR (FNR):          0.3977
# False Positive Rate:0.9841
# TP=223263, TN=13905, FP=863135, FN=147437
# Time elapsed:       16.22s
# Saved metrics to ../fed/data-test/randpos-evasion_trained-30-30-200_no-retraining/fgsm/after_adv_eps_0.24_advtrained_RandPos-PGD-Evasion-30-30-200.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.25} ===
# Accuracy:           0.1851
# Precision:          0.2010
# Recall:             0.5858
# F1:                 0.2993
# ASR (FNR):          0.4142
# False Positive Rate:0.9843
# TP=217170, TN=13726, FP=863314, FN=153530
# Time elapsed:       16.56s
# Saved metrics to ../fed/data-test/randpos-evasion_trained-30-30-200_no-retraining/fgsm/after_adv_eps_0.25_advtrained_RandPos-PGD-Evasion-30-30-200.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.26} ===
# Accuracy:           0.1801
# Precision:          0.1965
# Recall:             0.5697
# F1:                 0.2922
# ASR (FNR):          0.4303
# False Positive Rate:0.9846
# TP=211182, TN=13519, FP=863521, FN=159518
# Time elapsed:       15.58s
# Saved metrics to ../fed/data-test/randpos-evasion_trained-30-30-200_no-retraining/fgsm/after_adv_eps_0.26_advtrained_RandPos-PGD-Evasion-30-30-200.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.27} ===
# Accuracy:           0.1751
# Precision:          0.1919
# Recall:             0.5535
# F1:                 0.2850
# ASR (FNR):          0.4465
# False Positive Rate:0.9848
# TP=205168, TN=13311, FP=863729, FN=165532
# Time elapsed:       15.00s
# Saved metrics to ../fed/data-test/randpos-evasion_trained-30-30-200_no-retraining/fgsm/after_adv_eps_0.27_advtrained_RandPos-PGD-Evasion-30-30-200.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.28} ===
# Accuracy:           0.1706
# Precision:          0.1878
# Recall:             0.5388
# F1:                 0.2785
# ASR (FNR):          0.4612
# False Positive Rate:0.9850
# TP=199725, TN=13130, FP=863910, FN=170975
# Time elapsed:       18.42s
# Saved metrics to ../fed/data-test/randpos-evasion_trained-30-30-200_no-retraining/fgsm/after_adv_eps_0.28_advtrained_RandPos-PGD-Evasion-30-30-200.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.29} ===
# Accuracy:           0.1659
# Precision:          0.1834
# Recall:             0.5234
# F1:                 0.2716
# ASR (FNR):          0.4766
# False Positive Rate:0.9852
# TP=194028, TN=12987, FP=864053, FN=176672
# Time elapsed:       15.93s
# Saved metrics to ../fed/data-test/randpos-evasion_trained-30-30-200_no-retraining/fgsm/after_adv_eps_0.29_advtrained_RandPos-PGD-Evasion-30-30-200.json
# === Attack: FastGradientMethod, kwargs: {'eps': 0.3} ===
# Accuracy:           0.1615
# Precision:          0.1792
# Recall:             0.5090
# F1:                 0.2651
# ASR (FNR):          0.4910
# False Positive Rate:0.9853
# TP=188682, TN=12880, FP=864160, FN=182018
# Time elapsed:       16.61s
# Saved metrics to ../fed/data-test/randpos-evasion_trained-30-30-200_no-retraining/fgsm/after_adv_eps_0.3_advtrained_RandPos-PGD-Evasion-30-30-200.json

# %%
# Get clean baseline 
print("> Before Clean Test")
before_clean_out = clean_data_test(
    model, classifier, x_test, y_test, 
    checkpoint_file=checkpoint_file, data_file=data_file,
    save_path=adv_save_dir,
    filename=f"clean.json",
    save_results=True
)
# Out:
# > Before Clean Test
# torch.Size([124774, 10, 2])
# 0.9976138469777732
# 0.959778796870785
# Model got 1231979/1247740 right.
# Accuracy: 0.9873683619984933, Precision: 0.9976138469777732, Recall: 0.959778796870785, F1 Score: 0.9783306592093668
# 877040, 70.29028483498165% Zeroes, 370700 Non Zero entries.
# Saved to ../fed/data-test/randpos-evasion_trained-30-30-200_no-retraining/clean.json

# %% [markdown]
# #### Adv Training

# %%
## Simple training - pgd at 0.05
from art.defences.trainer import AdversarialTrainer
import torch 

# Training vars
adv_train_eps = 0.00
adv_train_epochs = 20
adv_train_ratio = 1.0

# Init vars
name = get_filename_from_path(checkpoint_file)

print(f"=== Adversarial training: {name} | eps:  {adv_train_eps} ===")

adv_save_dir = f"../fed/data-test/randpos2_pgd-{adv_train_eps}_epochs-{adv_train_epochs}_trained-30-30-200_ratio-{adv_train_ratio}"
os.makedirs(adv_save_dir, exist_ok=True)

# Get clean baseline 
print("> Before Clean Test")
before_clean_out = clean_data_test(
    model, classifier, x_test, y_test, 
    checkpoint_file=checkpoint_file, data_file=data_file,
    save_path=adv_save_dir,
    filename=f"before_clean_advtrained_{name}.json",
    save_results=True
)

# Check condition 1
print ("> Before Adv Test")
before_adv_out = adv_test(
    classifier, x_test, y_test, 
    checkpoint_file=checkpoint_file, data_file=data_file,
    end_index=len(y_test.numpy()),
    path=adv_save_dir,
    filename=f"before_adv_eps_{adv_train_eps}_advtrained_{name}.json",
    Attack=ProjectedGradientDescent,
    eps=adv_train_eps,
    max_iter = 5
)

# Run adv training
# freeze_benign_and_cols keeps rcvTime (col 0) untouched, same threat model as
# adv_test's freeze_cols default, and additionally only lets the attack perturb
# timesteps labeled attacker=1 - a real attacker can't manipulate benign
# messages from other vehicles, so FGSM/PGD shouldn't be allowed to "cheat" by
# moving benign traffic during training either.
print("> Running Adv Training")
attack = freeze_benign_and_cols(
    ProjectedGradientDescent(
        classifier, eps=adv_train_eps, max_iter=5,
        eps_step=2.5 * adv_train_eps / 5
    ),
    freeze_cols=(0,3)
)
trainer = AdversarialTrainer(classifier, attacks=attack, ratio=adv_train_ratio)
trainer.fit(x_train_np, y_train_np, nb_epochs=adv_train_epochs)

# Re-evaluate after adversarial training
print("> After Clean Test")
after_clean_out = clean_data_test(
    model, classifier, x_test, y_test, 
    checkpoint_file=checkpoint_file, data_file=data_file,
    save_path=adv_save_dir,
    filename=f"clean.json",
    save_results=True
)

# print("> After Adv Test")
after_adv_f1 = []
# for i in range(1, 31):
#     eps = float(i/100)
#     after_adv_out = adv_test(
#         classifier, x_test, y_test, 
#         checkpoint_file=checkpoint_file, data_file=data_file,
#         end_index=len(y_test.numpy()),
#         path=adv_save_dir + "/fgsm",
#         filename=f"after_adv_eps_{eps}_advtrained_{name}.json",
#         Attack=FastGradientMethod,
#         eps=eps,
#     )
#     after_adv_f1.append(after_adv_out["metrics"]["f1"])


# Save the adversarially-trained weights (loadable via utils.functions.load_model_checkpoint)
ckpt_out = f"{adv_save_dir}/advtrained_{name}.ckpt"
torch.save(model.learner.state_dict(), ckpt_out)
print(f"Saved adversarially-trained checkpoint to {ckpt_out}")

import json
config = {
    "eps": adv_train_eps,
    "adv_train_epochs": adv_train_epochs,
    "adv_train_ratio": adv_train_ratio,
    "checkpoint_file": checkpoint_file,
    "attack": "ProjectedGradientDescent",
    "name": name,
}

with open(f"{adv_save_dir}/config.json", "w") as f:
    json.dump(config, f, indent=4)
    print("saved:", f"{adv_save_dir}/config.json")
# Out:
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# Checkpoint path exists!
# === Adversarial training: RandPos-PGD-Evasion-30-30-200 | eps:  0.99 ===
# > Before Clean Test
# torch.Size([124774, 10, 2])
# 0.9976138469777732
# 0.959778796870785
# Model got 1231979/1247740 right.
# Accuracy: 0.9873683619984933, Precision: 0.9976138469777732, Recall: 0.959778796870785, F1 Score: 0.9783306592093668
# 877040, 70.29028483498165% Zeroes, 370700 Non Zero entries.
# Saved to ../fed/data-test/randpos2_pgd-0.99_epochs-20_trained-30-30-200_ratio-1.0/before_clean_advtrained_RandPos-PGD-Evasion-30-30-200.json
# > Before Adv Test
# === Attack: ProjectedGradientDescent, kwargs: {'eps': 0.99, 'max_iter': 5} ===
# PGD - Batches:   0%|          | 0/3900 [00:00<?, ?it/s]
# Accuracy:           0.1062
# Precision:          0.1312
# Recall:             0.3574
# F1:                 0.1920
# ASR (FNR):          0.6426
# False Positive Rate:1.0000
# TP=132500, TN=7, FP=877033, FN=238200
# Time elapsed:       69.82s
# Saved metrics to ../fed/data-test/randpos2_pgd-0.99_epochs-20_trained-30-30-200_ratio-1.0/before_adv_eps_0.99_advtrained_RandPos-PGD-Evasion-30-30-200.json
# > Running Adv Training
# Precompute adv samples:   0%|          | 0/1 [00:00<?, ?it/s]
# Adversarial training epochs:   0%|          | 0/20 [00:00<?, ?it/s]
# > After Clean Test
# torch.Size([124774, 10, 2])
# 0.9999838008935427
# 0.8326247639600756
# Model got 1185689/1247740 right.
# Accuracy: 0.9502692868706621, Precision: 0.9999838008935427, Recall: 0.8326247639600756, F1 Score: 0.9086624303203461
# 877040, 70.29028483498165% Zeroes, 370700 Non Zero entries.
# Saved to ../fed/data-test/randpos2_pgd-0.99_epochs-20_trained-30-30-200_ratio-1.0/clean.json
# Saved adversarially-trained checkpoint to ../fed/data-test/randpos2_pgd-0.99_epochs-20_trained-30-30-200_ratio-1.0/advtrained_RandPos-PGD-Evasion-30-30-200.ckpt
# saved: ../fed/data-test/randpos2_pgd-0.99_epochs-20_trained-30-30-200_ratio-1.0/config.json

# %%
x_batch = x_train.numpy()[:32]
y_batch = y_train.numpy()[:32]
x_adv = attack.generate(x_batch, y=y_batch)

benign = (y_batch != 1)
assert np.array_equal(x_adv[benign], x_batch[benign]), "benign timesteps were perturbed!"
assert not np.array_equal(x_adv[~benign], x_batch[~benign]), "attacker timesteps weren't touched at all"
assert np.array_equal(x_adv[:, :, (0,3)], x_batch[:, :, (0,3)]), "frozen cols moved"

fully_benign_windows = benign.all(axis=1)
assert np.array_equal(x_adv[fully_benign_windows], x_batch[fully_benign_windows]), "all-benign window changed"
print("max perturbation on attacker rows:", np.abs(x_adv[~benign] - x_batch[~benign]).max(), "(should be <= eps)")
# Out:
# max perturbation on attacker rows: 0.99 (should be <= eps)

# %%
diffs = np.abs(x_adv[~benign] - x_batch[~benign])   # only attacker cells, unfrozen cols
print("mean:", diffs.mean(), "median:", np.median(diffs))
print("fraction near eps bound (>0.9):", (diffs > 0.9).mean())
# Out:
# mean: 0.31041077 median: 0.2314905
# fraction near eps bound (>0.9): 0.0875

# %%
import json
config = {
    "eps": adv_train_eps,
    "adv_train_epochs": adv_train_epochs,
    "adv_train_ratio": adv_train_ratio,
    "checkpoint_file": checkpoint_file,
    "attack": "ProjectedGradientDescent",
    "name": name,
}

with open(f"{adv_save_dir}/config.json", "w") as f:
    json.dump(config, f, indent=4)
    print("saved:", f"{adv_save_dir}/config.json")
# Out:
# saved: ../fed/data-test/randpos_pgd-0.99_epochs-5_trained-30-30-200/config.json

# %%
## Find lowerbound threshold - lowest eps that still
lo_eps = 0.07 # fgsm, from the previously done eps sweep, f1 = 0.7079755805153897 < 0.77

# %%
## Find upperbound threshold - highest eps that starts making benign wrong

import json, time, torch
# When f1 is at least 20 pts down from og (so 0.77)

# ratio = 0.5, epochs = 5, eps = 0.2 -> ran until eps = 0.99, ratio to low? (high-eps-iterative)
# ratio = 1.0, epochs = 5, eps = 0.1 -> clean f1 score dec immediately, ratio to high? (high-eps-iterative-ratio-1.0)
# ratio = 0.7, epochs = 5, eps = 0.1 -> running current (high-eps-iterative-ratio-0.7)

# Defined
clean_f1 = 0.976470669379591
threshold_diff = 0.2
working_eps = 0.9

# Training Hyperparams
adv_train_epochs = 5
adv_train_ratio = 0.7

# Var definitions
x_train_np = x_train.numpy()
y_train_np = y_train.numpy()
name = get_filename_from_path(checkpoint_file)
index = 1

# run once

while index < 2:
    start = time.time()
    print(f"\n\n>>> New eps: {working_eps}")
    # Reload classifier
    index = index + 1
    model, classifier = get_model_classifier(checkpoint_file)
    adv_save_dir = f"../fed/data-test/freeze-col-test/iter-{index}"
    os.makedirs(adv_save_dir, exist_ok=True)
    print(f"Saving to: {adv_save_dir}")

    ## Adv train model
    print("> Running Adv Training")
    attack = freeze_attack_cols(FastGradientMethod(classifier, eps=working_eps), freeze_cols=(0,))
    trainer = AdversarialTrainer(classifier, attack, ratio=adv_train_ratio)
    trainer.fit(x_train_np, y_train_np, nb_epochs=adv_train_epochs, batch_size=64)

    # Save model
    ckpt_out = f"{adv_save_dir}/advtrained_{name}.ckpt"
    torch.save(model.learner.state_dict(), ckpt_out)
    print(f"Saved adversarially-trained checkpoint to {ckpt_out}")

    ## Test model
    after_clean_out = clean_data_test(
        model, classifier, x_test, y_test, 
        checkpoint_file=checkpoint_file, data_file=data_file,
        save_path=adv_save_dir,
        filename=f"after_clean_advtrained_{name}.json",
        save_results=True
    )

    # Save config
    

    # Check if f1 is below
    adv_f1 = after_clean_out["wrapper"]["f1"]
    if (adv_f1 < clean_f1 - threshold_diff): 
        print(f"BREAKING WITH EPS {working_eps}")
        break
    else:
        print(f"f1 = {adv_f1} >  {clean_f1 - threshold_diff}")
        working_eps = round(working_eps + 0.01, 2)
        print(f"Increasing eps to {working_eps}")

print("goodbye world")


    
    

"""
- Start at ~ 0.2 eps
- Adv train model on the # of eps (save the model)
- Run clean test (and SAVE it)
- Check if it's below the threshold

* Can try just doing 10 points.. later (or just see from data)
"""
# Out:
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# >>> New eps: 0.9
# Checkpoint path exists!
# Saving to: ../fed/data-test/freeze-col-test/iter-2
# > Running Adv Training
# Precompute adv samples: 100%|██████████| 1/1 [00:00<00:00, 58254.22it/s]
# Adversarial training epochs: 100%|██████████| 5/5 [07:05<00:00, 85.16s/it]
# Saved adversarially-trained checkpoint to ../fed/data-test/freeze-col-test/iter-2/advtrained_RandomPos-final.ckpt
# Saved to ../fed/data-test/freeze-col-test/iter-2/after_clean_advtrained_RandomPos-final.json
# f1 = 0.9955288715845922 >  0.7764706693795911
# Increasing eps to 0.91
# goodbye world
# "\n- Start at ~ 0.2 eps\n- Adv train model on the # of eps (save the model)\n- Run clean test (and SAVE it)\n- Check if it's below the threshold\n\n* Can try just doing 10 points.. later (or just see from data)\n"

# %%
# y_train_np.sum(axis=1)[102]
# Out:
# np.int64(0)

# %%
## Find upperbound threshold - highest eps that starts making benign wrong

import json, time, torch
import numpy as np
# When f1 is at least 20 pts down from og (so 0.77)

# ratio = 0.5, epochs = 5, eps = 0.2 -> ran until eps = 0.99, ratio to low? (high-eps-iterative)
# ratio = 1.0, epochs = 5, eps = 0.1 -> clean f1 score dec immediately, ratio to high? (high-eps-iterative-ratio-1.0)
# ratio = 0.7, epochs = 5, eps = 0.1 -> running current (high-eps-iterative-ratio-0.7)

# Defined
clean_f1 = 0.976470669379591
threshold_diff = 0.2
working_eps = 0.1

# Training Hyperparams
adv_train_epochs = 5

# Var definitions
x_train_np = x_train.numpy()
y_train_np = (y_train.numpy() == 1).all(axis=1).astype(np.int64)
name = get_filename_from_path(checkpoint_file)
index = 2

# run once

while index < 3:
    start = time.time()
    print(f"\n\n>>> New eps: {working_eps}")
    # Reload classifier
    index = index + 1
    model, classifier = get_model_classifier(checkpoint_file, collapsed=True)
    classifier._reduce_labels = True
    adv_save_dir = f"../fed/data-test/trades-test/iter-{index}"
    os.makedirs(adv_save_dir, exist_ok=True)
    print(f"Saving to: {adv_save_dir}")

    ## Adv train model
    print("> Running Adv Training")
    attack = FastGradientMethod(classifier, eps=working_eps)
    trainer = AdversarialTrainerTRADESPyTorch(classifier, attack=attack, beta=0.6)
    trainer.fit(x_train_np, y_train_np, nb_epochs=adv_train_epochs, batch_size=64)

    # Save model
    ckpt_out = f"{adv_save_dir}/advtrained_{name}.ckpt"
    torch.save(model.learner.state_dict(), ckpt_out)
    print(f"Saved adversarially-trained checkpoint to {ckpt_out}")

    ## Test model
    after_clean_out = clean_data_test(
        model, classifier, x_test, y_test, 
        checkpoint_file=checkpoint_file, data_file=data_file,
        save_path=adv_save_dir,
        filename=f"after_clean_advtrained_{name}.json",
        save_results=True,
        collapsed=True
    )

    # Save config
    config = {
        "eps": working_eps,
        "adv_train_epochs": adv_train_epochs,
        "beta": 0.6,
        "clean_f1_baseline": clean_f1,
        "threshold_diff": threshold_diff,
        "index": index,
        "checkpoint_file": checkpoint_file,
        "name": name,
        "timeElapsedSec": (time.time() - start)
    }

    with open(f"{adv_save_dir}/config.json", "w") as f:
        json.dump(config, f, indent=4)

    # Check if f1 is below
    adv_f1 = after_clean_out["wrapper"]["f1"]
    if (adv_f1 < clean_f1 - threshold_diff): 
        print(f"BREAKING WITH EPS {working_eps}")
        break
    else:
        print(f"f1 = {adv_f1} >  {clean_f1 - threshold_diff}")
        working_eps = round(working_eps + 0.01, 2)
        print(f"Increasing eps to {working_eps}")

print("goodbye world")


    
    

"""
- Start at ~ 0.2 eps
- Adv train model on the # of eps (save the model)
- Run clean test (and SAVE it)
- Check if it's below the threshold

* Can try just doing 10 points.. later (or just see from data)
"""
# Out:
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# >>> New eps: 0.1
# Checkpoint path exists!
# Saving to: ../fed/data-test/trades-test/iter-3
# > Running Adv Training
# Adversarial Training TRADES - Epochs: 100%|██████████| 5/5 [12:13<00:00, 146.73s/it]
# Saved adversarially-trained checkpoint to ../fed/data-test/trades-test/iter-3/advtrained_RandomPos-final.ckpt
# Saved to ../fed/data-test/trades-test/iter-3/after_clean_advtrained_RandomPos-final.json
# f1 = 0.9970922762743267 >  0.7764706693795911
# Increasing eps to 0.11
# goodbye world
# "\n- Start at ~ 0.2 eps\n- Adv train model on the # of eps (save the model)\n- Run clean test (and SAVE it)\n- Check if it's below the threshold\n\n* Can try just doing 10 points.. later (or just see from data)\n"

# %%
min(3, 1)
# Out:
# 1
